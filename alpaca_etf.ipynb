# %%
pip install alpaca_trade_api
# Out:
# Collecting alpaca_trade_api
#   Downloading alpaca_trade_api-3.0.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy>=1.11.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (1.21.5)
# Requirement already satisfied: pandas>=0.18.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (1.4.2)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (1.26.9)
# Collecting deprecation==2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: aiohttp==3.8.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (3.8.1)
# Requirement already satisfied: requests<3,>2 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (2.27.1)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (10.4)
# Requirement already satisfied: PyYAML==6.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (6.0)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from alpaca_trade_api) (0.58.0)
# Collecting msgpack==1.0.3
#   Downloading msgpack-1.0.3-cp39-cp39-macosx_10_9_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (4.0.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (5.2.0)
# Requirement already satisfied: packaging in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from deprecation==2.1.0->alpaca_trade_api) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp==3.8.1->alpaca_trade_api) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18.1->alpaca_trade_api) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>2->alpaca_trade_api) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>2->alpaca_trade_api) (2021.10.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/lor/opt/anaconda3/lib/python3.9/site-packages (from packaging->deprecation==2.1.0->alpaca_trade_api) (3.0.4)
# Installing collected packages: msgpack, deprecation, alpaca-trade-api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.5
#     Uninstalling msgpack-1.0.5:
#       Successfully uninstalled msgpack-1.0.5
# Successfully installed alpaca-trade-api-3.0.0 deprecation-2.1.0 msgpack-1.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing the api and instantiating the rest client according to our keys
import alpaca_trade_api as api

API_KEY = "AKX3R3280A8K7V68O18N"
API_SECRET = "qfXZfukG5xyWLpWynDM5BcLHVat1bewK4kWEzfWX"
alpaca = api.REST(API_KEY, API_SECRET)

# %%
# Setting parameters before calling method
symbol = "SPY"
timeframe = "1Minute"
start = "2021-01-01"
end = "2021-01-30"
# Retrieve daily bars for SPY in a dataframe and printing the first 5 rows
spy_bars = alpaca.get_bars(symbol, timeframe, start, end).df
spy_bars
# Out:
#                                open    high       low   close  volume  \
# timestamp
# 2021-01-04 09:00:00+00:00  375.6400  375.69  375.6400  375.69    2606
# 2021-01-04 09:01:00+00:00  375.6900  375.81  375.6900  375.79   16041
# 2021-01-04 09:02:00+00:00  375.8400  375.88  375.7900  375.82   12514
# 2021-01-04 09:04:00+00:00  375.9000  376.04  375.9000  375.91    8995
# 2021-01-04 09:05:00+00:00  375.9000  375.90  375.8800  375.88    4550
# ...                             ...     ...       ...     ...     ...
# 2021-01-30 00:55:00+00:00  369.2800  369.28  369.2800  369.28     497
# 2021-01-30 00:56:00+00:00  369.3501  369.40  369.3501  369.40    7361
# 2021-01-30 00:57:00+00:00  369.3600  369.45  369.3500  369.45    7361
# 2021-01-30 00:58:00+00:00  369.4500  369.45  369.3000  369.30    3505
# 2021-01-30 00:59:00+00:00  369.4500  369.45  369.4500  369.45    1853
#
#                            trade_count        vwap
# timestamp
# 2021-01-04 09:00:00+00:00           21  375.678688
# 2021-01-04 09:01:00+00:00           44  375.791473
# 2021-01-04 09:02:00+00:00           27  375.834458
# 2021-01-04 09:04:00+00:00           46  376.004726
# 2021-01-04 09:05:00+00:00           10  375.893297
# ...                                ...         ...
# 2021-01-30 00:55:00+00:00           18  369.338410
# 2021-01-30 00:56:00+00:00           73  369.395016
# 2021-01-30 00:57:00+00:00          107  369.421431
# 2021-01-30 00:58:00+00:00          102  369.436879
# 2021-01-30 00:59:00+00:00           47  369.436784
#
# [16118 rows x 7 columns]
